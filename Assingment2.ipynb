# %%
import pandas as pd

# %%
df=pd.read_csv('D:\College\Third Year\DataScience\StudentPerformance.csv')

# %%
df1=df
df2=df1
df3=df
df4=df

# %%
df
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3     male        71.0           85.0             77             96.0
# 4     male        68.0           86.0             76              NaN
# 5   female        94.0           86.0             61            100.0
# 6     male        75.0           79.0             66            -99.0
# 7   female         NaN            NaN             66             95.0
# 8     male        66.0           88.0             66             88.0
# 9     male        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 11    male        76.0           84.0            -99              NaN
# 12  female        74.0           79.0             79             98.0
#
#     club_join_year  placement_offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
df.isnull()
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0    False       False          False          False            False
# 1    False       False          False          False            False
# 2    False       False          False          False            False
# 3    False       False          False          False            False
# 4    False       False          False          False             True
# 5    False       False          False          False            False
# 6    False       False          False          False            False
# 7    False        True           True          False            False
# 8    False       False          False          False            False
# 9    False       False          False          False            False
# 10   False       False          False          False            False
# 11   False       False          False          False             True
# 12   False       False          False          False            False
#
#     club_join_year  placement_offer
# 0            False            False
# 1            False            False
# 2            False            False
# 3            False            False
# 4            False            False
# 5            False            False
# 6            False            False
# 7            False            False
# 8            False            False
# 9            False            False
# 10           False            False
# 11           False            False
# 12           False            False

# %%
df.isnull().sum()
# Out:
# gender             0
# math_score         1
# reading_score      1
# writing_score      0
# placement_score    2
# club_join_year     0
# placement_offer    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['gender', 'math_score', 'reading_score', 'writing_score',
#        'placement_score', 'club_join_year', 'placement_offer'],
#       dtype='object')

# %%
df.isnull().any()
# Out:
# gender             False
# math_score          True
# reading_score       True
# writing_score      False
# placement_score     True
# club_join_year     False
# placement_offer    False
# dtype: bool

# %%
pd.isnull(df["math_score"]).sum()
# Out:
# 1

# %%
df.notnull()
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0     True        True           True           True             True
# 1     True        True           True           True             True
# 2     True        True           True           True             True
# 3     True        True           True           True             True
# 4     True        True           True           True            False
# 5     True        True           True           True             True
# 6     True        True           True           True             True
# 7     True       False          False           True             True
# 8     True        True           True           True             True
# 9     True        True           True           True             True
# 10    True        True           True           True             True
# 11    True        True           True           True            False
# 12    True        True           True           True             True
#
#     club_join_year  placement_offer
# 0             True             True
# 1             True             True
# 2             True             True
# 3             True             True
# 4             True             True
# 5             True             True
# 6             True             True
# 7             True             True
# 8             True             True
# 9             True             True
# 10            True             True
# 11            True             True
# 12            True             True

# %%
df.notnull().sum()
# Out:
# gender             13
# math_score         12
# reading_score      12
# writing_score      13
# placement_score    11
# club_join_year     13
# placement_offer    13
# dtype: int64

# %%
df.head()
df1=df

# %%
df[df['writing_score'].isnull()].index.tolist()
# Out:
# []

# %%
import numpy as np

# %%
df.isnull().sum
()
# Out:
# ()

# %%
df.replace(to_replace=np.nan, value=70)
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3     male        71.0           85.0             77             96.0
# 4     male        68.0           86.0             76             70.0
# 5   female        94.0           86.0             61            100.0
# 6     male        75.0           79.0             66            -99.0
# 7   female        70.0           70.0             66             95.0
# 8     male        66.0           88.0             66             88.0
# 9     male        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 11    male        76.0           84.0            -99             70.0
# 12  female        74.0           79.0             79             98.0
#
#     club_join_year  placement_offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %% [markdown]
# Deleting Null Values

# %%
df3.isnull().sum()
# Out:
# gender             0
# math_score         1
# reading_score      1
# writing_score      0
# placement_score    2
# club_join_year     0
# placement_offer    0
# dtype: int64

# %%
df3[df3['math_score'].isnull()].index.tolist()
# Out:
# [7]

# %%
df3[df3['reading_score'].isnull()].index.tolist()
# Out:
# [7]

# %%
df3.dropna()
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3     male        71.0           85.0             77             96.0
# 5   female        94.0           86.0             61            100.0
# 6     male        75.0           79.0             66            -99.0
# 8     male        66.0           88.0             66             88.0
# 9     male        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 12  female        74.0           79.0             79             98.0
#
#     club_join_year  placement_offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 5             2019                1
# 6             2020                1
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 12            2019                2

# %%
df4
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3     male        71.0           85.0             77             96.0
# 4     male        68.0           86.0             76              NaN
# 5   female        94.0           86.0             61            100.0
# 6     male        75.0           79.0             66            -99.0
# 7   female         NaN            NaN             66             95.0
# 8     male        66.0           88.0             66             88.0
# 9     male        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 11    male        76.0           84.0            -99              NaN
# 12  female        74.0           79.0             79             98.0
#
#     club_join_year  placement_offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
df4.dropna(axis=1)
# Out:
#     gender  writing_score  club_join_year  placement_offer
# 0   female             64            2020                2
# 1   female             76            2018                3
# 2   female             66            2020                2
# 3     male             77            2018                1
# 4     male             76            2021                3
# 5   female             61            2019                1
# 6     male             66            2020                1
# 7   female             66            2019                3
# 8     male             66            2020                3
# 9     male             61            2021                2
# 10  female             65            2021                1
# 11    male            -99            2020                2
# 12  female             79            2019                2
