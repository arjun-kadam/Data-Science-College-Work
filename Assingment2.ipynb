# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df=pd.read_csv('D:\College\Third Year\DataScience\StudentPerformance.csv')

# %%
df1=df
df2=df1
df3=df
df4=df

# %%
df
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3     male        71.0           85.0             77             96.0
# 4     male        68.0           86.0             76              NaN
# 5   female        94.0           86.0             61            100.0
# 6     male        75.0           79.0             66            -99.0
# 7   female         NaN            NaN             66             95.0
# 8     male        66.0           88.0             66             88.0
# 9     male        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 11    male        76.0           84.0            -99              NaN
# ...

# %%
df.isnull()
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0    False       False          False          False            False
# 1    False       False          False          False            False
# 2    False       False          False          False            False
# 3    False       False          False          False            False
# 4    False       False          False          False             True
# 5    False       False          False          False            False
# 6    False       False          False          False            False
# 7    False        True           True          False            False
# 8    False       False          False          False            False
# 9    False       False          False          False            False
# 10   False       False          False          False            False
# 11   False       False          False          False             True
# ...

# %%
series = pd.isnull(df["reading_score"])
df[series]
# Out:
#    gender  math_score  reading_score  writing_score  placement_score  \
# 7  female         NaN            NaN             66             95.0
#
#    club_join_year  placement_offer
# 7            2019                3

# %%
df.notnull()
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0     True        True           True           True             True
# 1     True        True           True           True             True
# 2     True        True           True           True             True
# 3     True        True           True           True             True
# 4     True        True           True           True            False
# 5     True        True           True           True             True
# 6     True        True           True           True             True
# 7     True       False          False           True             True
# 8     True        True           True           True             True
# 9     True        True           True           True             True
# 10    True        True           True           True             True
# 11    True        True           True           True            False
# ...

# %%
seseries = pd.notnull(df["reading_score"])
df[series]
# Out:
#    gender  math_score  reading_score  writing_score  placement_score  \
# 7  female         NaN            NaN             66             95.0
#
#    club_join_year  placement_offer
# 7            2019                3

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder ()
df['gender'] = le.fit_transform(df['gender'])
newdf=df
df
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0        0        63.0           84.0             64             84.0
# 1        0        71.0           80.0             76             86.0
# 2        0        64.0           81.0             66             81.0
# 3        1        71.0           85.0             77             96.0
# 4        1        68.0           86.0             76              NaN
# 5        0        94.0           86.0             61            100.0
# 6        1        75.0           79.0             66            -99.0
# 7        0         NaN            NaN             66             95.0
# 8        1        66.0           88.0             66             88.0
# 9        1        70.0           79.0             61             87.0
# 10       0       -99.0           80.0             65             85.0
# 11       1        76.0           84.0            -99              NaN
# ...

# %%
df['gender'].replace({1: "male", 0: "female"}, inplace=True)
df
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3     male        71.0           85.0             77             96.0
# 4     male        68.0           86.0             76              NaN
# 5   female        94.0           86.0             61            100.0
# 6     male        75.0           79.0             66            -99.0
# 7   female         NaN            NaN             66             95.0
# 8     male        66.0           88.0             66             88.0
# 9     male        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 11    male        76.0           84.0            -99              NaN
# ...

# %%
ndf=df
ndf.fillna(0)
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3     male        71.0           85.0             77             96.0
# 4     male        68.0           86.0             76              0.0
# 5   female        94.0           86.0             61            100.0
# 6     male        75.0           79.0             66            -99.0
# 7   female         0.0            0.0             66             95.0
# 8     male        66.0           88.0             66             88.0
# 9     male        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 11    male        76.0           84.0            -99              0.0
# ...

# %%
m_v=df['reading_score'].mean()
df['reading_score'].fillna(value=m_v, inplace=True)
df
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0      84.000000             64             84.0
# 1   female        71.0      80.000000             76             86.0
# 2   female        64.0      81.000000             66             81.0
# 3     male        71.0      85.000000             77             96.0
# 4     male        68.0      86.000000             76              NaN
# 5   female        94.0      86.000000             61            100.0
# 6     male        75.0      79.000000             66            -99.0
# 7   female         NaN      82.583333             66             95.0
# 8     male        66.0      88.000000             66             88.0
# 9     male        70.0      79.000000             61             87.0
# 10  female       -99.0      80.000000             65             85.0
# 11    male        76.0      84.000000            -99              NaN
# ...

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0      84.000000             64             84.0
# 1   female        71.0      80.000000             76             86.0
# 2   female        64.0      81.000000             66             81.0
# 3     male        71.0      85.000000             77             96.0
# 4     male        68.0      86.000000             76            -99.0
# 5   female        94.0      86.000000             61            100.0
# 6     male        75.0      79.000000             66            -99.0
# 7   female       -99.0      82.583333             66             95.0
# 8     male        66.0      88.000000             66             88.0
# 9     male        70.0      79.000000             61             87.0
# 10  female       -99.0      80.000000             65             85.0
# 11    male        76.0      84.000000            -99            -99.0
# ...

# %%
ndf.dropna()
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3     male        71.0           85.0             77             96.0
# 5   female        94.0           86.0             61            100.0
# 6     male        75.0           79.0             66            -99.0
# 8     male        66.0           88.0             66             88.0
# 9     male        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 12  female        74.0           79.0             79             98.0
#
#     club_join_year  placement_offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# ...

# %%
ndf.dropna(how = 'all')
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0      84.000000             64             84.0
# 1   female        71.0      80.000000             76             86.0
# 2   female        64.0      81.000000             66             81.0
# 3     male        71.0      85.000000             77             96.0
# 4     male        68.0      86.000000             76              NaN
# 5   female        94.0      86.000000             61            100.0
# 6     male        75.0      79.000000             66            -99.0
# 7   female         NaN      82.583333             66             95.0
# 8     male        66.0      88.000000             66             88.0
# 9     male        70.0      79.000000             61             87.0
# 10  female       -99.0      80.000000             65             85.0
# 11    male        76.0      84.000000            -99              NaN
# ...

# %%
ndf.dropna(axis = 1)
# Out:
#     gender  reading_score  writing_score  club_join_year  placement_offer
# 0   female      84.000000             64            2020                2
# 1   female      80.000000             76            2018                3
# 2   female      81.000000             66            2020                2
# 3     male      85.000000             77            2018                1
# 4     male      86.000000             76            2021                3
# 5   female      86.000000             61            2019                1
# 6     male      79.000000             66            2020                1
# 7   female      82.583333             66            2019                3
# 8     male      88.000000             66            2020                3
# 9     male      79.000000             61            2021                2
# 10  female      80.000000             65            2021                1
# 11    male      84.000000            -99            2020                2
# ...

# %%
new_data =ndf.dropna (axis = 0, how ='any')
new_data
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3     male        71.0           85.0             77             96.0
# 5   female        94.0           86.0             61            100.0
# 6     male        75.0           79.0             66            -99.0
# 8     male        66.0           88.0             66             88.0
# 9     male        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 12  female        74.0           79.0             79             98.0
#
#     club_join_year  placement_offer
# 0             2020                2
# 1             2018                3
# 2             2020                2
# 3             2018                1
# ...

# %%
col =['reading_score', 'reading_score', 'writing_score', 'placement_score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['reading_score']>90))
print(np.where(df['writing_score']>90))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
fig, ax =plt.subplots(figsize = (18,10))
ax.scatter(df['reading_score'], df['writing_score'])
plt.show()

# %%
print(np.where((df['reading_score']<50) & (df['writing_score']>1)))
print(np.where((df['reading_score']>85) & (df['writing_score']<3)))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
z = np.abs(stats.zscore(df['reading_score']))

# %%
print(z)
# Out:
# 0     0.472390
# 1     0.861418
# 2     0.527966
# 3     0.805843
# 4     1.139295
# 5     1.139295
# 6     1.194870
# 7     0.000000
# 8     1.806199
# 9     1.194870
# 10    0.861418
# 11    0.472390
# 12    1.194870
# Name: reading_score, dtype: float64

# %%
threshold = 0.18

# %%
sample_outliers = np.where(z)

# %%
sorted_rscore= sorted(df['reading_score'])

# %%
sorted_rscore
# Out:
# [79.0,
#  79.0,
#  79.0,
#  80.0,
#  80.0,
#  81.0,
#  82.58333333333333,
#  84.0,
#  84.0,
#  85.0,
#  86.0,
#  86.0,
#  88.0]

# %%
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 80.0 85.0

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 72.5 92.5

# %%
new_df=df
for i in sample_outliers:new_df.drop(i,inplace=True)
new_df
# Out:
#    gender  math_score  reading_score  writing_score  placement_score  \
# 7  female         NaN      82.583333             66             95.0
#
#    club_join_year  placement_offer
# 7            2019                3

# %%
df=pd.read_csv("StudentPerformance.csv")

# %%
df_stud=df
ninetieth_percentile = np.percentile(df_stud['reading_score'], 90)
b = np.where(df_stud['reading_score']>ninetieth_percentile,
ninetieth_percentile, df_stud['reading_score'])
print("New array:",b)
# Out:
# New array: [84. 80. 81. 85. 86. 86. 79. nan 88. 79. 80. 84. 79.]

# %%
col = ['reading_score']

df.boxplot(col)
# Out:
# <Axes: >

# %%
median=np.median(sorted_rscore)
median
# Out:
# 82.58333333333333

# %%
df
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3     male        71.0           85.0             77             96.0
# 4     male        68.0           86.0             76              NaN
# 5   female        94.0           86.0             61            100.0
# 6     male        75.0           79.0             66            -99.0
# 7   female         NaN            NaN             66             95.0
# 8     male        66.0           88.0             66             88.0
# 9     male        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 11    male        76.0           84.0            -99              NaN
# ...

# %%
refined_df['reading_score'] = np.where(refined_df['reading_score'] <lwr_bound, median,refined_df['reading_score'])

# %%
df
# Out:
#     gender  math_score  reading_score  writing_score  placement_score  \
# 0   female        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3     male        71.0           85.0             77             96.0
# 4     male        68.0           86.0             76              NaN
# 5   female        94.0           86.0             61            100.0
# 6     male        75.0           79.0             66            -99.0
# 7   female         NaN            NaN             66             95.0
# 8     male        66.0           88.0             66             88.0
# 9     male        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 11    male        76.0           84.0            -99              NaN
# ...

# %%
col = ['reading_score']
refined_df.boxplot(col)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
df['reading_score'].plot(kind ='hist')
df['log_math'] = np.log10(df['reading_score'])
plt.show()

# %%
df['log_math'].plot(kind = 'hist')
plt.show()
